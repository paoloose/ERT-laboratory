# %%
# %pip install resipy matplotlib pandas

# %% [markdown]
# # ResIPy
#
# https://gitlab.com/hkex/resipy
#
# Sample data: https://gitlab.com/hkex/resipy/-/tree/master/src/examples/
#
# Features overview: https://www.youtube.com/watch?v=cvqMAIAt-Do

# %%
import resipy

# %%
k = resipy.Project(typ='R2')
k.filterUnpaired()
k.createSurvey('syscal.csv')
k.invert(parallel=True)
k.showResults()
# Out:
# Working directory is: /home/paolo/Dev/ert-notes/notebooks/.venv/lib/python3.11/site-packages/resipy
# clearing dirname
# 308/344 reciprocal measurements found.
# 0 measurements error > 20 %
# Creating triangular mesh...done (1786 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
# it looks like wine32 is missing, you should install it.
# multiarch needs to be enabled first.  as root, please
# execute "dpkg --add-architecture i386 && apt-get update &&
# apt-get install wine32:i386"
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.02 <<
#
#  >> D a t e : 26 - 06 - 2023
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
# ...
