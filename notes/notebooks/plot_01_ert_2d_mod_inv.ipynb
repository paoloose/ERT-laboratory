# %%
# Checkout www.pygimli.org for more examples

# %% [markdown]
# # 2D ERT modeling and inversion

# %%
import matplotlib.pyplot as plt
import numpy as np

import pygimli as pg
import pygimli.meshtools as mt
from pygimli.physics import ert

# %% [markdown]
# ## Geometry definition
# Create geometry definition for the modelling domain. ``worldMarker=True``
# indicates the default boundary conditions for the ERT

# %%
world = mt.createWorld(start=[-50, 0], end=[50, -50], layers=[-1, -5],
                       worldMarker=True)

# %% [markdown]
# Create some heterogeneous circular anomaly

# %%
block = mt.createCircle(
    pos=[-5, -3.], radius=[4, 1], marker=4,
    boundaryMarker=10, area=0.1
)

# %%
poly = mt.createPolygon([(1,-4), (2,-1.5), (4,-2), (5,-2),
                         (8,-3), (5,-3.5), (3,-4.5)], isClosed=True,
                         addNodes=3, interpolate='spline', marker=5)

# %% [markdown]
# Merge geometry definition into a Piecewise Linear Complex (PLC)

# %%
geom = world + block + poly

# %% [markdown]
# Optional: show the geometry

# %%
pg.show(geom)
mt.exportPLC(geom, 'data/geom.poly')

# %% [markdown]
# ## Synthetic data generation
# Create a Dipole Dipole ('dd') measuring scheme with 21 electrodes.

# %%
scheme = ert.createData(elecs=np.linspace(start=-15, stop=15, num=21), schemeName='dd')

# %% [markdown]
# Put all electrode (aka sensors) positions into the PLC to enforce mesh
# refinement. Due to experience, its convenient to add further refinement
# nodes in a distance of 10% of electrode spacing to achieve sufficient
# numerical accuracy.

# %%
for p in scheme.sensors():
    geom.createNode(p)
    geom.createNode(p - [0, 0.1])

# Create a mesh for the finite element modelling with appropriate mesh quality.
mesh = mt.createMesh(geom, quality=34)

# Create a map to set resistivity values in the appropriate regions
# [[regionNumber, resistivity], [regionNumber, resistivity], [...]
rhomap = [[1, 100.],
          [2, 75.],
          [3, 50.],
          [4, 150.],
          [5, 25]]

# Take a look at the mesh and the resistivity distribution
pg.show(mesh, data=rhomap, label=pg.unit('res'), showMesh=True)
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x7fe65cd93690>)

# %% [markdown]
# Perform the modeling with the mesh and the measuring scheme itself
# and return a data container with apparent resistivity values,
# geometric factors and estimated data errors specified by the noise setting.
# The noise is also added to the data. Here 1% plus 1µV.
# Note, we force a specific noise seed as we want reproducable results for
# testing purposes.

# %%
data = ert.simulate(mesh, scheme=scheme, res=rhomap, noiseLevel=1,
                    noiseAbs=1e-6, seed=1337)

pg.info(np.linalg.norm(data['err']), np.linalg.norm(data['rhoa']))
pg.info('Simulated data', data)
pg.info('The data contains:', data.dataMap().keys())

pg.info('Simulated rhoa (min/max)', min(data['rhoa']), max(data['rhoa']))
pg.info('Selected data noise %(min/max)', min(data['err'])*100, max(data['err'])*100)
# Out:
# ModellingBase::setMesh() copying new mesh ... Found datafile: 21 electrodes
# Found: 21 free-electrodes
# rMin = 0.75, rMax = 60
# NGauLeg + NGauLag for inverse Fouriertransformation: 11 + 4
# Found non-Neumann domain
# 0.0446919 s
# FOP updating mesh dependencies ... 4.337e-06 s
# Calculating response for model: min = 25 max = 150
# Allocating memory for primary potential...... 0.000741604
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.529208s
# Response: min = 43.6475 max = 102.718 mean = 71.3742
# Reciprocity rms(modelReciprocity) 0.140597%, max: 0.449979%
# relativeError set to a value > 0.5 .. assuming this is a percentage Error level dividing them by 100
# Data error estimate (min:max)  0.010000294838286121 : 0.01056761917552525
# 09/07/23 - 10:34:59 - pyGIMLi - INFO - 0.13172095457607064 956.0725038881353
# 09/07/23 - 10:34:59 - pyGIMLi - INFO - Simulated data Data: Sensors: 21 data: 171, nonzero entries: ['a', 'b', 'err', 'k', 'm', 'n', 'rhoa', 'valid']
# 09/07/23 - 10:34:59 - pyGIMLi - INFO - The data contains: ['a', 'b', 'err', 'i', 'ip', 'iperr', 'k', 'm', 'n', 'r', 'rhoa', 'u', 'valid']
# 09/07/23 - 10:34:59 - pyGIMLi - INFO - Simulated rhoa (min/max) 42.792496044211 104.19891011722967
# 09/07/23 - 10:34:59 - pyGIMLi - INFO - Selected data noise %(min/max) 1.0000294838286121 1.056761917552525

# %% [markdown]
# Optional: you can filter all values and tokens in the data container.
# Its possible that there are some negative data values due to noise and
# huge geometric factors. So we need to remove them.

# %%
data.remove(data['rhoa'] < 0)
pg.info('Filtered rhoa (min/max)', min(data['rhoa']), max(data['rhoa']))

# You can save the data for further use
data.save('simple.dat')

# You can take a look at the data
ert.show(data)
# Out:
# 09/07/23 - 10:34:59 - pyGIMLi - INFO - Filtered rhoa (min/max) 42.792496044211 104.19891011722967
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x7fe65a95ee90>)

# %% [markdown]
# ## Inversion with the ERTManager
# Initialize the ERTManager, e.g. with a data container or a filename.

# %%
mgr = ert.ERTManager('simple.dat')

# %% [markdown]
# Run the inversion with the preset data. The Inversion mesh will be created
# with default settings.

# %%
inv = mgr.invert(lam=20, verbose=True)
np.testing.assert_approx_equal(mgr.inv.chi2(), 0.7, significant=1)
# Out:
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Found 2 regions.
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Found 2 regions.
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 987 Cells: 1824 Boundaries: 1442
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Use median(data values)=67.9439561191829
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Created startmodel from forward operator: 287 [67.9439561191829,...,67.9439561191829]
# 09/07/23 - 10:35:00 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 49
#   Input segments: 50
#   Input holes: 0
#
#   Mesh vertices: 266
#   Mesh triangles: 456
#   Mesh edges: 721
#   Mesh exterior boundary edges: 74
#   Mesh interior boundary edges: 15
#   Mesh subsegments (constrained edges): 89
#
# min/max(dweight) = 94.6287/99.9971
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7fe65811c810>
# Data transformation: <pygimli.core._pygimli_.RTransLogLU object at 0x7fe6525fae80>
# Model transformation: <pygimli.core._pygimli_.RTransLog object at 0x7fe658189d50>
# min/max (data): 42.79/104
# min/max (error): 1%/1.06%
# min/max (start model): 67.94/67.94
# --------------------------------------------------------------------------------
# Calculating response for model: min = 67.944 max = 67.944
# Allocating memory for primary potential...... 0.000178679
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.203s
# Response: min = 67.7421 max = 68.0324 mean = 67.8983
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 94.6287/99.9971
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 401 x 287
# check Jacobian: wrong dimensions: (0x0) should be (171x287)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.00151819:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.278473s
# sens sum: median = 1.04613 min = 0.951278 max = 1.25063
# ... 0.279159 s
# min data = 42.7925 max data = 104.199 (171)
# min error = 0.0100003 max error = 0.0105676 (171)
# min response = 67.7421 max response = 68.0324 (171)
# calc without reference model
# 0: rms/rrms(data, response) = 16.3794/22.3279%
# 0: chi^2(data, response, error, log) = 506.257
# 0: Phi = 86570 + 0 * 20 = 86570
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 16.282 max = 137.407
# Using existing primary potentials.
# Forward: time: 0.211874s
# Response: min = 37.7581 max = 103.741 mean = 69.0775
# Reciprocity rms(modelReciprocity) 0.355708%, max: 1.28589%
# 1: LS newModel: min = 16.282; max = 137.407
# 1: LS newResponse: min = 37.6025; max = 103.942
# 1: rms/rrms(data, LS newResponse) = 3.08164/5.4523%
# 1: chi^2(data, LS newResponse, error, log) = 31.8359
# 1: Phi = 5443.94+10.8289*20=5660.51
# Linesearch tau = 0.86
# Calculating response for model: min = 19.887 max = 124.506
# Using existing primary potentials.
# Forward: time: 0.172803s
# Response: min = 41.646 max = 97.813 mean = 68.9631
# Reciprocity rms(modelReciprocity) 0.292401%, max: 1.06299%
# chi² = 14.2 (dPhi = 97.01%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 19.887; max = 124.506
# 1: Response: min = 41.5099; max = 97.9779
# 1: rms/rrms(data, Response) = 2.87692/3.70586%
# 1: chi^2(data, Response, error, log) = 14.2047
# 1: Phi = 2429.01+8.00904*20=2589.19
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.000179377:time: 0.217696s
# sens sum: median = 1.14152 min = 0.954525 max = 1.30603
# ... 0.218396 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 23.0249 max = 146.329
# Using existing primary potentials.
# Forward: time: 0.168691s
# Response: min = 42.5129 max = 103.276 mean = 70.6081
# Reciprocity rms(modelReciprocity) 0.249986%, max: 0.760379%
# chi² = 3.04 (dPhi = 74.29%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Linesearch tau = 1
# 2: Model: min = 23.0249; max = 146.329
# 2: Response: min = 42.403; max = 103.382
# 2: rms/rrms(data, Response) = 1.11152/1.75167%
# 2: chi^2(data, Response, error, log) = 3.03815
# 2: Phi = 519.523+7.31107*20=665.744
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.0002393:time: 0.250817s
# sens sum: median = 1.13005 min = 0.955636 max = 1.29662
# ... 0.251606 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 22.9602 max = 146.74
# Using existing primary potentials.
# Forward: time: 0.142066s
# Response: min = 43.5416 max = 103.373 mean = 71.2237
# Reciprocity rms(modelReciprocity) 0.252272%, max: 0.770351%
# chi² = 0.7 (dPhi = 60.27%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.70)                   #
# ################################################################################
# Linesearch tau = 1
# 3: Model: min = 22.9602; max = 146.74
# 3: Response: min = 43.3743; max = 103.471
# 3: rms/rrms(data, Response) = 0.583257/0.844662%
# 3: chi^2(data, Response, error, log) = 0.703803
# 3: Phi = 120.35+7.20717*20=264.494

# %% [markdown]
# Let the ERTManger show you the model of the last successful run and how it
# fits the data. Shows data, model response, and model.

# %%
mgr.showResultAndFit()
meshPD = pg.Mesh(mgr.paraDomain) # Save copy of para mesh for plotting later

# %% [markdown]
# You can also provide your own mesh (e.g., a structured grid if you like them)
# Note, that x and y coordinates needs to be in ascending order to ensure that
# all the cells in the grid have the correct orientation, i.e., all cells need
# to be numbered counter-clockwise and the boundary normal directions need to
# point outside.

# %%
inversionDomain = pg.createGrid(x=np.linspace(start=-18, stop=18, num=33),
                                y=-pg.cat([0], pg.utils.grange(0.5, 8, n=5))[::-1],
                                marker=2)

# %% [markdown]
# ## Inversion with custom mesh
# The inversion domain for ERT problems needs a boundary that represents the
# far regions in the subsurface of the halfspace.
# Give a cell marker lower than the marker for the inversion region, the lowest
# cell marker in the mesh will be the inversion boundary region by default.

# %%
grid = pg.meshtools.appendTriangleBoundary(inversionDomain, marker=1,
                                           xbound=50, ybound=50)
pg.show(grid, markers=True)
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x7fe65228f550>)

# %% [markdown]
# The Inversion can be called with data and mesh as argument as well

# %%
model = mgr.invert(data, mesh=grid, lam=20, verbose=True)
np.testing.assert_approx_equal(mgr.inv.chi2(), 1.4, significant=2)
# Out:
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Found 2 regions.
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1462 Cells: 2164 Boundaries: 1842
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Use median(data values)=67.9439561191829
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Created startmodel from forward operator: 160 [67.9439561191829,...,67.9439561191829]
# 09/07/23 - 10:35:04 - pyGIMLi - INFO - Starting inversion.
# Found datafile: 21 electrodes
# Found: 21 node-electrodes
# Found non-Neumann domain
#  updateDataDependency:: cleaning primpot
# Reset region parameter
# RegionManager copying mesh ...0.00493955 s
# create NeighborInfos ... 2.5059e-05 s
# analysing mesh ... 2 regions.
# creating para domain ... 0.00131958 s
# creating para domain ... 0.00131058 s
# ModellingBase::setMesh() copying new mesh ... Found datafile: 21 electrodes
# Found: 21 free-electrodes
# Found non-Neumann domain
# 0.0190415 s
# FOP updating mesh dependencies ... 1.6436e-05 s
# ModellingBase::setMesh() copying new mesh ... 0.0104721 s
# FOP updating mesh dependencies ... 3.8669e-05 s
# min/max(dweight) = 94.6287/99.9971
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7fe65811c810>
# Data transformation: <pygimli.core._pygimli_.RTransLogLU object at 0x7fe6525fae80>
# Model transformation: <pygimli.core._pygimli_.RTransLog object at 0x7fe658189d50>
# min/max (data): 42.79/104
# min/max (error): 1%/1.06%
# min/max (start model): 67.94/67.94
# --------------------------------------------------------------------------------
# Calculating response for model: min = 67.944 max = 67.944
# Allocating memory for primary potential...... 0.000289706
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.264821s
# Response: min = 67.3385 max = 74.1129 mean = 68.5192
# Reciprocity rms(modelReciprocity) 2.82273%, max: 9.57838%
# min/max(dweight) = 94.6287/99.9971
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 283 x 160
# check Jacobian: wrong dimensions: (171x287) should be (171x160)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.00020619:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.131652s
# sens sum: median = 1.03129 min = 0.89362 max = 1.14707
# ... 0.132101 s
# min data = 42.7925 max data = 104.199 (171)
# min error = 0.0100003 max error = 0.0105676 (171)
# min response = 67.4301 max response = 73.0161 (171)
# calc without reference model
# 0: rms/rrms(data, response) = 15.7027/21.8315%
# 0: chi^2(data, response, error, log) = 468.393
# 0: Phi = 80095.3 + 0 * 20 = 80095.3
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 14.9461 max = 173.448
# Using existing primary potentials.
# Forward: time: 0.23044s
# Response: min = 32.212 max = 104.949 mean = 65.8349
# Reciprocity rms(modelReciprocity) 3.21303%, max: 12.3228%
# 1: LS newModel: min = 14.9461; max = 173.448
# 1: LS newResponse: min = 32.1803; max = 104.924
# 1: rms/rrms(data, LS newResponse) = 7.20189/11.979%
# 1: chi^2(data, LS newResponse, error, log) = 172.976
# 1: Phi = 29579+26.7884*20=30114.7
# Linesearch tau = 0.67
# Calculating response for model: min = 24.6345 max = 127.307
# Using existing primary potentials.
# Forward: time: 0.214039s
# Response: min = 41.8795 max = 91.2767 mean = 66.5422
# Reciprocity rms(modelReciprocity) 3.05625%, max: 11.3612%
# chi² = 77.93 (dPhi = 83.06%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 24.6345; max = 127.307
# 1: Response: min = 41.8557; max = 91.2637
# 1: rms/rrms(data, Response) = 6.63593/8.45359%
# 1: chi^2(data, Response, error, log) = 77.9311
# 1: Phi = 13326.2+12.0253*20=13566.7
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.000154539:time: 0.168471s
# sens sum: median = 1.0469 min = 0.723012 max = 1.20805
# ... 0.168938 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 18.4822 max = 160.235
# Using existing primary potentials.
# Forward: time: 0.209557s
# Response: min = 44.5189 max = 102.417 mean = 71.6243
# Reciprocity rms(modelReciprocity) 3.16642%, max: 12.1817%
# 2: LS newModel: min = 18.4822; max = 160.235
# 2: LS newResponse: min = 44.3675; max = 102.52
# 2: rms/rrms(data, LS newResponse) = 1.93782/3.03744%
# 2: chi^2(data, LS newResponse, error, log) = 8.25543
# 2: Phi = 1411.68+16.0856*20=1733.39
# Linesearch tau = 0.83
# Calculating response for model: min = 19.4074 max = 154.09
# Using existing primary potentials.
# Forward: time: 0.207146s
# Response: min = 44.2311 max = 100.458 mean = 70.716
# Reciprocity rms(modelReciprocity) 3.14417%, max: 12.036%
# chi² = 5.37 (dPhi = 91.06%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 19.4074; max = 154.09
# 2: Response: min = 44.0624; max = 100.54
# 2: rms/rrms(data, Response) = 1.80556/2.33432%
# 2: chi^2(data, Response, error, log) = 5.36924
# 2: Phi = 918.14+14.7108*20=1212.36
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.000143657:time: 0.170444s
# sens sum: median = 1.07426 min = 0.799342 max = 1.2822
# ... 0.170898 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 18.6821 max = 171.859
# Using existing primary potentials.
# Forward: time: 0.292061s
# Response: min = 42.5442 max = 103.538 mean = 70.9945
# Reciprocity rms(modelReciprocity) 3.20566%, max: 12.4614%
# 3: LS newModel: min = 18.6821; max = 171.859
# 3: LS newResponse: min = 42.5024; max = 103.538
# 3: rms/rrms(data, LS newResponse) = 1.05251/1.58953%
# 3: chi^2(data, LS newResponse, error, log) = 2.4946
# 3: Phi = 426.577+17.1285*20=769.146
# Linesearch tau = 0.7
# Calculating response for model: min = 18.8968 max = 166.323
# Using existing primary potentials.
# Forward: time: 0.288227s
# Response: min = 43.1215 max = 102.609 mean = 70.903
# Reciprocity rms(modelReciprocity) 3.18665%, max: 12.3316%
# chi² = 2.02 (dPhi = 44.6%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 18.8968; max = 166.323
# 3: Response: min = 42.9559; max = 102.635
# 3: rms/rrms(data, Response) = 1.05072/1.4213%
# 3: chi^2(data, Response, error, log) = 2.02431
# 3: Phi = 346.157+16.2765*20=671.687
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.000252616:time: 0.1746s
# sens sum: median = 1.07103 min = 0.76972 max = 1.30338
# ... 0.175077 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 18.8584 max = 173.357
# Using existing primary potentials.
# Forward: time: 0.32339s
# Response: min = 43.2968 max = 103.322 mean = 71.162
# Reciprocity rms(modelReciprocity) 3.2125%, max: 12.5235%
# chi² = 1.51 (dPhi = 11.03%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... Linesearch tau = 1
# 4: Model: min = 18.8584; max = 173.357
# 4: Response: min = 43.1348; max = 103.344
# 4: rms/rrms(data, Response) = 0.869681/1.23112%
# 4: chi^2(data, Response, error, log) = 1.50869
# 4: Phi = 257.986+16.9799*20=597.583
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.000143313:time: 0.155236s
# chi² = 1.43 (dPhi = 2.04%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... sens sum: median = 1.07176 min = 0.768413 max = 1.31233
# ... 0.156017 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 18.9123 max = 174.755
# Using existing primary potentials.
# Forward: time: 0.207436s
# Response: min = 43.7093 max = 103.36 mean = 71.3862
# Reciprocity rms(modelReciprocity) 3.21739%, max: 12.5754%
# 5: LS newModel: min = 18.9123; max = 174.755
# 5: LS newResponse: min = 43.5205; max = 103.378
# 5: rms/rrms(data, LS newResponse) = 0.856751/1.22237%
# 5: chi^2(data, LS newResponse, error, log) = 1.47079
# 5: Phi = 251.506+17.0892*20=593.291
# Linesearch tau = 0.55
# Calculating response for model: min = 18.888 max = 174.125
# Using existing primary potentials.
# Forward: time: 0.210704s
# Response: min = 43.535 max = 103.343 mean = 71.2852
# Reciprocity rms(modelReciprocity) 3.21519%, max: 12.552%
# 5: Model: min = 18.888; max = 174.125
# 5: Response: min = 43.3467; max = 103.362
# 5: rms/rrms(data, Response) = 0.849424/1.20149%
# 5: chi^2(data, Response, error, log) = 1.43063
# 5: Phi = 244.637+17.0384*20=585.405
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(4/4-std::mt): 0.000181284:time: 0.201245s
# sens sum: median = 1.07224 min = 0.771044 max = 1.31364
# ... 0.201716 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 18.9085 max = 175.119
# Using existing primary potentials.
# Forward: time: 0.263447s
# Response: min = 43.5848 max = 103.382 mean = 71.329
# Reciprocity rms(modelReciprocity) 3.21918%, max: 12.5843%
# chi² = 1.42 (dPhi = 0.09%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 0.09 (< 2.0%)                 #
# ################################################################################
# 6: LS newModel: min = 18.9085; max = 175.119
# 6: LS newResponse: min = 43.3972; max = 103.398
# 6: rms/rrms(data, LS newResponse) = 0.84115/1.19452%
# 6: chi^2(data, LS newResponse, error, log) = 1.41136
# 6: Phi = 241.343+17.183*20=585.004
# Linesearch tau = 0.68
# Calculating response for model: min = 18.9019 max = 174.801
# Using existing primary potentials.
# Forward: time: 0.314335s
# Response: min = 43.5703 max = 103.37 mean = 71.3151
# Reciprocity rms(modelReciprocity) 3.2179%, max: 12.574%
# 6: Model: min = 18.9019; max = 174.801
# 6: Response: min = 43.3811; max = 103.386
# 6: rms/rrms(data, Response) = 0.843395/1.19622%
# 6: chi^2(data, Response, error, log) = 1.41626
# 6: Phi = 242.181+17.1359*20=584.899

# %% [markdown]
# ## Visualization
# You can of course get access to mesh and model and plot them for your own.
# Note that the cells of the parametric domain of your mesh might be in
# a different order than the values in the model array if regions are used.
# The manager can help to permutate them into the right order.

# %%
modelPD = mgr.paraModel(model)  # do the mapping
pg.show(mgr.paraDomain, modelPD, label='Model', cMap='Spectral_r',
        logScale=True, cMin=25, cMax=150)

pg.info('Inversion stopped with chi² = {0:.3}'.format(mgr.fw.chi2()))

fig, (ax1, ax2, ax3) = plt.subplots(3,1, sharex=True, sharey=True, figsize=(8,7))

pg.show(mesh, rhomap, ax=ax1, hold=True, cMap="Spectral_r", logScale=True,
        orientation="vertical", cMin=25, cMax=150)
pg.show(meshPD, inv, ax=ax2, hold=True, cMap="Spectral_r", logScale=True,
        orientation="vertical", cMin=25, cMax=150)
mgr.showResult(ax=ax3, cMin=25, cMax=150, orientation="vertical")

labels = ["True model", "Inversion unstructured mesh", "Inversion regular grid"]
for ax, label in zip([ax1, ax2, ax3], labels):
    ax.set_xlim(mgr.paraDomain.xmin(), mgr.paraDomain.xmax())
    ax.set_ylim(mgr.paraDomain.ymin(), mgr.paraDomain.ymax())
    ax.set_title(label)
# Out:
# 09/07/23 - 10:35:08 - pyGIMLi - INFO - Inversion stopped with chi² = 1.42
